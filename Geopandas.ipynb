# %%
import geopandas as gpd
import pandas as pd

# %%
data = gpd.read_file('areas.csv')
data.rename({"ploygon" : "polygon"}, inplace=True, axis=1)

# %%
data.head()
# Out:
#   area_id  area_name                                            polygon  \
# 0       1  شیخ بهایی  POLYGON((51.3909726846557 35.7751072901314,51....
# 1     152       هروی  POLYGON((51.48486 35.78824,51.49152 35.78556,5...
# 2       3  یوسف آباد  POLYGON((51.3850379287598 35.7443900961541,51....
# 3     117       ارتش  POLYGON((51.4920593202209 35.792153161708,51.4...
# 4      27       پونک  POLYGON((51.3425402487183 35.7643187950424,51....
#
#   zone_id zone_name geometry
# 0       1      مرکز     None
# 1       3  شمال شرق     None
# 2       1      مرکز     None
# 3       2      شمال     None
# 4       4       غرب     None

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   area_id    26 non-null     object
#  1   area_name  26 non-null     object
#  2   polygon    26 non-null     object
#  3   zone_id    26 non-null     object
#  4   zone_name  26 non-null     object
#  5   geometry   0 non-null      geometry
# dtypes: geometry(1), object(5)
# memory usage: 1.3+ KB

# %%
data['geometry'] = gpd.GeoSeries.from_wkt(data['polygon'])

# %%
data = data.set_geometry('geometry')

# %%
data.drop(['polygon'], axis=1, inplace=True)

# %%
data.plot()
# Out:
# <AxesSubplot:>
